# %%
import xml.etree.ElementTree as ET
import os
import numpy as np

points_list = [] # list of point sequences
points_lengths = [] # list of lengths of point sequences

xmax = 0
ymax = 0

# Iterate through xml files
file_num = 0
folders = os.listdir('original')
for folder in folders:
    samples = os.listdir('original/' + folder)
    for sample in samples:
        file_num += 1
        tree = ET.parse('original/' + folder + '/' + sample + '/strokesz.xml')
        root = tree.getroot()

        # Save the x-y-EOS series as another numpy array, put it in list
        points = []
        for stroke in root.find('StrokeSet').findall('Stroke'):
            point_set = stroke.findall('Point')
            end = len(point_set) - 1
            for i, point in enumerate(point_set):
                x = float(point.get('x'))
                y = float(point.get('y'))
                
                xmax = max(xmax, x)
                ymax = max(ymax, y)
                eos = float(i == end)
                points.append([x, y, eos])
    point_series = np.array(points, dtype=np.float64)
    points_list.append(point_series)
    points_lengths.append(point_series.shape[0])
    
print('Done parsing')
# Out:
# Done parsing

# %%
import torch
import random

# %%
class GeneratorCell(torch.nn.Module):
    def __init__(self, hidden_size, mixture_size):
        super(GeneratorCell, self).__init__()

        self.gru = torch.nn.GRU(input_size=3, hidden_size=hidden_size, batch_first=True)
        self.hidden_size= hidden_size
        self.mixture_size = mixture_size

        # for generating mixture weights
        self.linear1 = torch.nn.Linear(hidden_size, mixture_size)

        # for generating means
        self.linear2 = torch.nn.Linear(hidden_size, 2*mixture_size) 
        
        # for generating standard deviations
        self.linear5 = torch.nn.Linear(hidden_size, 2*mixture_size) 

        # for generating correlations
        self.linear3 = torch.nn.Linear(hidden_size, mixture_size) 

        # for generating EOS probability
        self.linear4 = torch.nn.Linear(hidden_size, 1)

    def forward(self, input_batch, seq_length):
        batch_size = input_batch.size()[0]
        mdn_output_batch = torch.zeros(batch_size, seq_length, 6*self.mixture_size + 1)
        output, hidden = self.gru(input_batch)
        for i in range(seq_length):
            mdn_input = output[:, i, :]
            
            gmm_weights = torch.nn.functional.softmax(self.linear1(mdn_input), dim=1)
            gmm_means = 1000*torch.nn.functional.relu(self.linear2(mdn_input))
            #gmm_means = 100*torch.exp(self.linear2(mdn_input))
            max_means = torch.ones(batch_size, 2*mixture_size, dtype=torch.double)
            max_means[:, :mixture_size] *= xmax
            max_means[:, mixture_size:] *= ymax
            gmm_means = torch.min(torch.stack([gmm_means, max_means]), 0)[0]
            gmm_stds = 100*torch.nn.functional.relu(self.linear5(mdn_input)) + 0.1*torch.ones(batch_size, 2*mixture_size)
            #gmm_stds = 10*torch.exp(self.linear5(mdn_input))
            gmm_corrs = torch.tanh(self.linear3(mdn_input))
            eos_prob = torch.sigmoid(self.linear4(mdn_input))
            mdn_output = torch.cat((gmm_weights, gmm_means, gmm_stds, gmm_corrs, eos_prob), 1)
            mdn_output_batch[:, i, :] = mdn_output
            
        return mdn_output_batch
    
    # Given some (x, y, EOS), return the distribution parameters for the next (x, y, EOS) and the next hidden state
    def get_next(self, input, hidden):
        output, hidden = self.gru(input.view(1, 1, 3), hidden)
        
        # get rid of sequence index in output
        output = output.squeeze(1)

        gmm_weights = torch.nn.functional.softmax(self.linear1(output), dim=1)
        gmm_means = 1000*torch.nn.functional.relu(self.linear2(output))
        #gmm_means = 100*torch.exp(self.linear2(output))
        gmm_stds = 10*torch.nn.functional.relu(self.linear5(output)) + 0.1*torch.ones(input_batch.size()[0], 2*mixture_size)
        #gmm_stds = 10*torch.exp(self.linear5(output)) + 0.1*torch.ones(input_batch.size()[0], 2*mixture_size)
        gmm_corrs = torch.tanh(self.linear3(output))
        eos_prob = torch.sigmoid(self.linear4(output))
        mdn_output = torch.cat((gmm_weights, gmm_means, gmm_stds, gmm_corrs, eos_prob), 1)
            
        return mdn_output, hidden

# %%
def log_likelihood_batched(input_batch, output_batch, min_length, mixture_size, batch_size):
    logprob = 0 # mean log probability of input data across batches
    
    # iterate through data points in sequence
    for seq_index in range(min_length - 1):
        data_point_batch = input_batch[:, seq_index + 1] # batch of next x-y-EOS values
        # iterate through Gaussians in mixture model
        prob = 0
        for k in range(mixture_size):
            # mixing coefficient lambda_k
            lambda_k = output_batch[:, seq_index, k]

            mu_x = output_batch[:, seq_index, mixture_size + k]
            mu_y = output_batch[:, seq_index, 2*mixture_size + k]
            
            loc = torch.stack([mu_x, mu_y]).view(-1, 2) #for passing to multivariate normal
            sigma_x = output_batch[:, seq_index, 3*mixture_size + k]
            sigma_y = output_batch[:, seq_index, 4*mixture_size + k]
            correlation = output_batch[:, seq_index, 5*mixture_size + k]

            cov = correlation*sigma_x*sigma_y
            cov_mat = torch.zeros((batch_size, 2, 2), dtype=torch.double)
            cov_mat[:, 0, 0] = sigma_x**2 + 0.01*torch.ones(batch_size)
            cov_mat[:, 0, 1] = cov
            cov_mat[:, 1, 0] = cov
            cov_mat[:, 1, 1] = sigma_y**2
            
            gaussian = torch.distributions.multivariate_normal.MultivariateNormal(loc, cov_mat)
            prob += lambda_k*torch.exp(gaussian.log_prob(data_point_batch[:, 0:2].double()))
        logprob += torch.sum(torch.log(prob + 0.001*torch.ones(batch_size)))/batch_size
        eos = data_point_batch[:, 2]
        not_eos = torch.ones(batch_size) - eos
        logprob += torch.sum(eos*torch.log(output_batch[:, seq_index, 6*mixture_size]))/batch_size #EOS probability
        logprob += torch.sum(not_eos*torch.log(1 - output_batch[:, seq_index, 6*mixture_size]))/batch_size #not-EOS probability
            
    return logprob

# %%
# Training loop
n_epochs = 100
n_iters = 50
hidden_size = 16
mixture_size = 5
batch_size = 15

model = GeneratorCell(hidden_size, mixture_size).double()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

losses = np.zeros(n_epochs) # For plotting

indices = list(range(len(points_list))) # Indices for random sampling (for batches)

# %%
for epoch in range(n_epochs):
    for iter in range(n_iters):
        print('Epoch: ' + str(epoch) + ' Iteration: ' + str(iter))
        index_list = random.sample(indices, batch_size) # random sampling of indices
        min_length = min([points_lengths[i] for i in index_list]) # list of sequence lengths
        min_length = min([200, min_length])
        input_batch = torch.autograd.Variable(torch.tensor([points_list[i][0:min_length] for i in index_list], dtype=torch.double))
        
        output_batch = model.forward(input_batch, min_length)

        optimizer.zero_grad()
        loss = -log_likelihood_batched(input_batch, output_batch, min_length, mixture_size, batch_size)
        loss.backward()
        optimizer.step()
        
        print('Loss: ' + str(loss.data))

        losses[epoch] += loss.data
# Out:
# Epoch: 0 Iteration: 0
# Loss: tensor(1502.7677, dtype=torch.float64)
# Epoch: 0 Iteration: 1
# Loss: tensor(1436.6634, dtype=torch.float64)
# Epoch: 0 Iteration: 2
# Loss: tensor(1415.3221, dtype=torch.float64)
# Epoch: 0 Iteration: 3
# Loss: tensor(1407.4313, dtype=torch.float64)
# Epoch: 0 Iteration: 4
# Loss: tensor(1414.9942, dtype=torch.float64)
# Epoch: 0 Iteration: 5
# Loss: tensor(1411.5983, dtype=torch.float64)
# Epoch: 0 Iteration: 6
# Loss: tensor(1411.8679, dtype=torch.float64)
# Epoch: 0 Iteration: 7
# Loss: tensor(1406.8509, dtype=torch.float64)
# Epoch: 0 Iteration: 8
# Loss: tensor(1412.4637, dtype=torch.float64)
# Epoch: 0 Iteration: 9
# Loss: tensor(1417.0724, dtype=torch.float64)
# Epoch: 0 Iteration: 10
# Loss: tensor(1421.1859, dtype=torch.float64)
# Epoch: 0 Iteration: 11
# Loss: tensor(1410.4457, dtype=torch.float64)
# Epoch: 0 Iteration: 12
# Loss: tensor(1407.3772, dtype=torch.float64)
# Epoch: 0 Iteration: 13
# Loss: tensor(1418.5284, dtype=torch.float64)
# Epoch: 0 Iteration: 14
# Loss: tensor(1410.8435, dtype=torch.float64)
# Epoch: 0 Iteration: 15
# Loss: tensor(1413.6393, dtype=torch.float64)
# Epoch: 0 Iteration: 16
# Loss: tensor(1410.2138, dtype=torch.float64)
# Epoch: 0 Iteration: 17
# Loss: tensor(1407.5312, dtype=torch.float64)
# Epoch: 0 Iteration: 18
# Loss: tensor(1409.2809, dtype=torch.float64)
# Epoch: 0 Iteration: 19
# Loss: tensor(1406.9731, dtype=torch.float64)
# Epoch: 0 Iteration: 20
# Loss: tensor(1410.5301, dtype=torch.float64)
# Epoch: 0 Iteration: 21
# Loss: tensor(1408.9948, dtype=torch.float64)
# Epoch: 0 Iteration: 22
# Loss: tensor(1409.3232, dtype=torch.float64)
# Epoch: 0 Iteration: 23
# Loss: tensor(1407.2138, dtype=torch.float64)
# Epoch: 0 Iteration: 24
# Loss: tensor(1409.8917, dtype=torch.float64)
# Epoch: 0 Iteration: 25
# Loss: tensor(1412.6682, dtype=torch.float64)
# Epoch: 0 Iteration: 26
# Loss: tensor(1409.2923, dtype=torch.float64)
# Epoch: 0 Iteration: 27
# Loss: tensor(1411.0630, dtype=torch.float64)
# Epoch: 0 Iteration: 28
# Loss: tensor(1410.2307, dtype=torch.float64)
# Epoch: 0 Iteration: 29
# Loss: tensor(1406.1479, dtype=torch.float64)
# Epoch: 0 Iteration: 30
# Loss: tensor(1404.7124, dtype=torch.float64)
# Epoch: 0 Iteration: 31
# Loss: tensor(1408.2273, dtype=torch.float64)
# Epoch: 0 Iteration: 32
# Loss: tensor(1405.8408, dtype=torch.float64)
# Epoch: 0 Iteration: 33
# Loss: tensor(1405.3986, dtype=torch.float64)
# Epoch: 0 Iteration: 34
# Loss: tensor(1405.9338, dtype=torch.float64)
# Epoch: 0 Iteration: 35
# Loss: tensor(1405.1157, dtype=torch.float64)
# Epoch: 0 Iteration: 36
# Loss: tensor(1407.1474, dtype=torch.float64)
# Epoch: 0 Iteration: 37
# Loss: tensor(1405.5415, dtype=torch.float64)
# Epoch: 0 Iteration: 38
# Loss: tensor(1408.0247, dtype=torch.float64)
# Epoch: 0 Iteration: 39
# Loss: tensor(1407.0256, dtype=torch.float64)
# Epoch: 0 Iteration: 40
# Loss: tensor(1409.3736, dtype=torch.float64)
# Epoch: 0 Iteration: 41
# Loss: tensor(1406.8364, dtype=torch.float64)
# Epoch: 0 Iteration: 42
# Loss: tensor(1408.1152, dtype=torch.float64)
# Epoch: 0 Iteration: 43
# Loss: tensor(1402.7095, dtype=torch.float64)
# Epoch: 0 Iteration: 44
# Loss: tensor(1408.0920, dtype=torch.float64)
# Epoch: 0 Iteration: 45
# Loss: tensor(1410.6428, dtype=torch.float64)
# Epoch: 0 Iteration: 46
# Loss: tensor(1414.3814, dtype=torch.float64)
# Epoch: 0 Iteration: 47
# Loss: tensor(1412.9725, dtype=torch.float64)
# Epoch: 0 Iteration: 48
# Loss: tensor(1402.2638, dtype=torch.float64)
# Epoch: 0 Iteration: 49
# Loss: tensor(1416.2707, dtype=torch.float64)
# Epoch: 1 Iteration: 0
# Loss: tensor(1411.7838, dtype=torch.float64)
# Epoch: 1 Iteration: 1
# Loss: tensor(1406.8745, dtype=torch.float64)
# Epoch: 1 Iteration: 2
# Loss: tensor(1411.8490, dtype=torch.float64)
# Epoch: 1 Iteration: 3
# Loss: tensor(1403.8021, dtype=torch.float64)
# Epoch: 1 Iteration: 4
# Loss: tensor(1406.1317, dtype=torch.float64)
# Epoch: 1 Iteration: 5
# Loss: tensor(1409.7259, dtype=torch.float64)
# Epoch: 1 Iteration: 6
# Loss: tensor(1408.4459, dtype=torch.float64)
# Epoch: 1 Iteration: 7
# Loss: tensor(1408.8239, dtype=torch.float64)
# Epoch: 1 Iteration: 8
# Loss: tensor(1413.3147, dtype=torch.float64)
# Epoch: 1 Iteration: 9
# Loss: tensor(1406.0475, dtype=torch.float64)
# Epoch: 1 Iteration: 10
# Loss: tensor(1409.1143, dtype=torch.float64)
# Epoch: 1 Iteration: 11
# Loss: tensor(1411.1337, dtype=torch.float64)
# Epoch: 1 Iteration: 12
# Loss: tensor(1410.9265, dtype=torch.float64)
# Epoch: 1 Iteration: 13
# Loss: tensor(1410.0257, dtype=torch.float64)
# Epoch: 1 Iteration: 14
# Loss: tensor(1406.4865, dtype=torch.float64)
# Epoch: 1 Iteration: 15
# Loss: tensor(1412.5745, dtype=torch.float64)
# Epoch: 1 Iteration: 16
# Loss: tensor(1404.5463, dtype=torch.float64)
# Epoch: 1 Iteration: 17
# Loss: tensor(1412.0298, dtype=torch.float64)
# Epoch: 1 Iteration: 18
# Loss: tensor(1410.0874, dtype=torch.float64)
# Epoch: 1 Iteration: 19
# Loss: tensor(1408.8260, dtype=torch.float64)
# Epoch: 1 Iteration: 20
# Loss: tensor(1406.3672, dtype=torch.float64)
# Epoch: 1 Iteration: 21
# Loss: tensor(1411.3030, dtype=torch.float64)
# Epoch: 1 Iteration: 22
# Loss: tensor(1411.0979, dtype=torch.float64)
# Epoch: 1 Iteration: 23
# Loss: tensor(1414.4320, dtype=torch.float64)
# Epoch: 1 Iteration: 24
# Loss: tensor(1402.8646, dtype=torch.float64)
# Epoch: 1 Iteration: 25
# Loss: tensor(1405.6601, dtype=torch.float64)
# Epoch: 1 Iteration: 26
# Loss: tensor(1412.1148, dtype=torch.float64)
# Epoch: 1 Iteration: 27
# Loss: tensor(1413.1467, dtype=torch.float64)
# Epoch: 1 Iteration: 28
# Loss: tensor(1409.4559, dtype=torch.float64)
# Epoch: 1 Iteration: 29
# Loss: tensor(1407.3870, dtype=torch.float64)
# Epoch: 1 Iteration: 30
# Loss: tensor(1407.1634, dtype=torch.float64)
# Epoch: 1 Iteration: 31
# Loss: tensor(1409.8710, dtype=torch.float64)
# Epoch: 1 Iteration: 32
# Loss: tensor(1409.2459, dtype=torch.float64)
# Epoch: 1 Iteration: 33
# Loss: tensor(1410.0985, dtype=torch.float64)
# Epoch: 1 Iteration: 34
# Loss: tensor(1404.3678, dtype=torch.float64)
# Epoch: 1 Iteration: 35
# Loss: tensor(1409.2629, dtype=torch.float64)
# Epoch: 1 Iteration: 36
# Loss: tensor(1406.6977, dtype=torch.float64)
# Epoch: 1 Iteration: 37
# Loss: tensor(1405.1914, dtype=torch.float64)
# Epoch: 1 Iteration: 38
# Loss: tensor(1404.1045, dtype=torch.float64)
# Epoch: 1 Iteration: 39
# Loss: tensor(1412.5653, dtype=torch.float64)
# Epoch: 1 Iteration: 40
# Loss: tensor(1413.0004, dtype=torch.float64)
# Epoch: 1 Iteration: 41
# Loss: tensor(1404.3195, dtype=torch.float64)
# Epoch: 1 Iteration: 42
# Loss: tensor(1407.7730, dtype=torch.float64)
# Epoch: 1 Iteration: 43
# Loss: tensor(1408.6280, dtype=torch.float64)
# Epoch: 1 Iteration: 44
# Loss: tensor(1411.3974, dtype=torch.float64)
# Epoch: 1 Iteration: 45
# Loss: tensor(1402.4710, dtype=torch.float64)
# Epoch: 1 Iteration: 46
# Loss: tensor(1409.0369, dtype=torch.float64)
# Epoch: 1 Iteration: 47
# Loss: tensor(1409.6678, dtype=torch.float64)
# Epoch: 1 Iteration: 48
# Loss: tensor(1408.4030, dtype=torch.float64)
# Epoch: 1 Iteration: 49
# Loss: tensor(1409.4519, dtype=torch.float64)
# Epoch: 2 Iteration: 0
# Loss: tensor(1411.3310, dtype=torch.float64)
# Epoch: 2 Iteration: 1
# Loss: tensor(1405.4994, dtype=torch.float64)
# Epoch: 2 Iteration: 2
# Loss: tensor(1406.3330, dtype=torch.float64)
# Epoch: 2 Iteration: 3
# Loss: tensor(1414.8666, dtype=torch.float64)
# Epoch: 2 Iteration: 4
# Loss: tensor(1412.5663, dtype=torch.float64)
# Epoch: 2 Iteration: 5
# Loss: tensor(1411.5184, dtype=torch.float64)
# Epoch: 2 Iteration: 6
# Loss: tensor(1406.1716, dtype=torch.float64)
# Epoch: 2 Iteration: 7
# Loss: tensor(1410.0740, dtype=torch.float64)
# Epoch: 2 Iteration: 8
# Loss: tensor(1408.0258, dtype=torch.float64)
# Epoch: 2 Iteration: 9
# Loss: tensor(1407.6106, dtype=torch.float64)
# Epoch: 2 Iteration: 10
# Loss: tensor(1403.6817, dtype=torch.float64)
# Epoch: 2 Iteration: 11
# Loss: tensor(1409.8665, dtype=torch.float64)
# Epoch: 2 Iteration: 12
# Loss: tensor(1404.6231, dtype=torch.float64)
# Epoch: 2 Iteration: 13
# Loss: tensor(1403.9438, dtype=torch.float64)
# Epoch: 2 Iteration: 14
# Loss: tensor(1406.6962, dtype=torch.float64)
# Epoch: 2 Iteration: 15
# Loss: tensor(1407.5718, dtype=torch.float64)
# Epoch: 2 Iteration: 16
# Loss: tensor(1405.6109, dtype=torch.float64)
# Epoch: 2 Iteration: 17
# Loss: tensor(1406.0601, dtype=torch.float64)
# Epoch: 2 Iteration: 18
# Loss: tensor(1408.7476, dtype=torch.float64)
# Epoch: 2 Iteration: 19
# Loss: tensor(1409.8733, dtype=torch.float64)
# Epoch: 2 Iteration: 20
# Loss: tensor(1406.7362, dtype=torch.float64)
# Epoch: 2 Iteration: 21
# Loss: tensor(1413.5996, dtype=torch.float64)
# Epoch: 2 Iteration: 22
# Loss: tensor(1407.8017, dtype=torch.float64)
# Epoch: 2 Iteration: 23
# Loss: tensor(1405.8308, dtype=torch.float64)
# Epoch: 2 Iteration: 24
# Loss: tensor(1406.9123, dtype=torch.float64)
# Epoch: 2 Iteration: 25
# Loss: tensor(1408.1914, dtype=torch.float64)
# Epoch: 2 Iteration: 26
# Loss: tensor(1408.4030, dtype=torch.float64)
# Epoch: 2 Iteration: 27
# Loss: tensor(1406.3226, dtype=torch.float64)
# Epoch: 2 Iteration: 28
# Loss: tensor(1410.4883, dtype=torch.float64)
# Epoch: 2 Iteration: 29
# Loss: tensor(1414.2046, dtype=torch.float64)
# Epoch: 2 Iteration: 30
# Loss: tensor(1407.6149, dtype=torch.float64)
# Epoch: 2 Iteration: 31
# Loss: tensor(1408.8536, dtype=torch.float64)
# Epoch: 2 Iteration: 32
# Loss: tensor(1411.3014, dtype=torch.float64)
# Epoch: 2 Iteration: 33
# Loss: tensor(1413.5369, dtype=torch.float64)
# Epoch: 2 Iteration: 34
# Loss: tensor(1409.4800, dtype=torch.float64)
# Epoch: 2 Iteration: 35
# Loss: tensor(1405.8439, dtype=torch.float64)
# Epoch: 2 Iteration: 36
# Loss: tensor(1413.1293, dtype=torch.float64)
# Epoch: 2 Iteration: 37
# Loss: tensor(1409.8763, dtype=torch.float64)
# Epoch: 2 Iteration: 38
# Loss: tensor(1407.0123, dtype=torch.float64)
# Epoch: 2 Iteration: 39
# Loss: tensor(1404.9307, dtype=torch.float64)
# Epoch: 2 Iteration: 40
# Loss: tensor(1411.1140, dtype=torch.float64)
# Epoch: 2 Iteration: 41
# Loss: tensor(1404.6279, dtype=torch.float64)
# Epoch: 2 Iteration: 42
# Loss: tensor(1407.3429, dtype=torch.float64)
# Epoch: 2 Iteration: 43
# Loss: tensor(1408.1984, dtype=torch.float64)
# Epoch: 2 Iteration: 44
# Loss: tensor(1406.2638, dtype=torch.float64)
# Epoch: 2 Iteration: 45
# Loss: tensor(1407.1364, dtype=torch.float64)
# Epoch: 2 Iteration: 46
# Loss: tensor(1407.3645, dtype=torch.float64)
# Epoch: 2 Iteration: 47
# Loss: tensor(1408.9131, dtype=torch.float64)
# Epoch: 2 Iteration: 48
# Loss: tensor(1404.2901, dtype=torch.float64)
# Epoch: 2 Iteration: 49
# Loss: tensor(1405.1710, dtype=torch.float64)
# Epoch: 3 Iteration: 0
# Loss: tensor(1409.3621, dtype=torch.float64)
# Epoch: 3 Iteration: 1
# Loss: tensor(1399.8922, dtype=torch.float64)
# Epoch: 3 Iteration: 2
# Loss: tensor(1407.3744, dtype=torch.float64)
# Epoch: 3 Iteration: 3
# Loss: tensor(1408.2551, dtype=torch.float64)
# Epoch: 3 Iteration: 4
# Loss: tensor(1406.7088, dtype=torch.float64)
# Epoch: 3 Iteration: 5
# Loss: tensor(1409.9872, dtype=torch.float64)
# Epoch: 3 Iteration: 6
# Loss: tensor(1406.9156, dtype=torch.float64)
# Epoch: 3 Iteration: 7
# Loss: tensor(1411.0123, dtype=torch.float64)
# Epoch: 3 Iteration: 8
# Loss: tensor(1407.9814, dtype=torch.float64)
# Epoch: 3 Iteration: 9
# Loss: tensor(1405.2293, dtype=torch.float64)
# Epoch: 3 Iteration: 10
# Loss: tensor(1406.0899, dtype=torch.float64)
# Epoch: 3 Iteration: 11
# Loss: tensor(1406.5178, dtype=torch.float64)
# Epoch: 3 Iteration: 12
# Loss: tensor(1406.7291, dtype=torch.float64)
# Epoch: 3 Iteration: 13
# Loss: tensor(1409.2426, dtype=torch.float64)
# Epoch: 3 Iteration: 14
# Loss: tensor(1410.5023, dtype=torch.float64)
# Epoch: 3 Iteration: 15
# Loss: tensor(1414.4858, dtype=torch.float64)
# Epoch: 3 Iteration: 16
# Loss: tensor(1407.1566, dtype=torch.float64)
# Epoch: 3 Iteration: 17
# Loss: tensor(1405.2937, dtype=torch.float64)
# Epoch: 3 Iteration: 18
# Loss: tensor(1404.4574, dtype=torch.float64)
# Epoch: 3 Iteration: 19
# Loss: tensor(1410.9153, dtype=torch.float64)
# Epoch: 3 Iteration: 20
# Loss: tensor(1410.2922, dtype=torch.float64)
# Epoch: 3 Iteration: 21
# Loss: tensor(1409.8743, dtype=torch.float64)
# Epoch: 3 Iteration: 22
# Loss: tensor(1407.5618, dtype=torch.float64)
# Epoch: 3 Iteration: 23
# Loss: tensor(1414.5080, dtype=torch.float64)
# Epoch: 3 Iteration: 24
# Loss: tensor(1407.3557, dtype=torch.float64)
# Epoch: 3 Iteration: 25
# Loss: tensor(1409.6601, dtype=torch.float64)
# Epoch: 3 Iteration: 26
# Loss: tensor(1407.7817, dtype=torch.float64)
# Epoch: 3 Iteration: 27
# Loss: tensor(1408.4084, dtype=torch.float64)
# Epoch: 3 Iteration: 28
# Loss: tensor(1408.4085, dtype=torch.float64)
# Epoch: 3 Iteration: 29
# Loss: tensor(1407.5737, dtype=torch.float64)
# Epoch: 3 Iteration: 30
# Loss: tensor(1410.0777, dtype=torch.float64)
# Epoch: 3 Iteration: 31
# Loss: tensor(1410.2881, dtype=torch.float64)
# Epoch: 3 Iteration: 32
# Loss: tensor(1404.6388, dtype=torch.float64)
# Epoch: 3 Iteration: 33
# Loss: tensor(1407.7729, dtype=torch.float64)
# Epoch: 3 Iteration: 34
# Loss: tensor(1406.9255, dtype=torch.float64)
# Epoch: 3 Iteration: 35
# Loss: tensor(1406.0704, dtype=torch.float64)
# Epoch: 3 Iteration: 36
# Loss: tensor(1403.9250, dtype=torch.float64)
# Epoch: 3 Iteration: 37
# Loss: tensor(1407.7730, dtype=torch.float64)
# Epoch: 3 Iteration: 38
# Loss: tensor(1404.7452, dtype=torch.float64)
# Epoch: 3 Iteration: 39
# Loss: tensor(1410.8550, dtype=torch.float64)
# Epoch: 3 Iteration: 40
# Loss: tensor(1409.9918, dtype=torch.float64)
# Epoch: 3 Iteration: 41
# Loss: tensor(1409.5477, dtype=torch.float64)
# Epoch: 3 Iteration: 42
# Loss: tensor(1406.0463, dtype=torch.float64)
# Epoch: 3 Iteration: 43
# Loss: tensor(1408.4319, dtype=torch.float64)
# Epoch: 3 Iteration: 44
# Loss: tensor(1412.7334, dtype=torch.float64)
# Epoch: 3 Iteration: 45
# Loss: tensor(1408.1942, dtype=torch.float64)
# Epoch: 3 Iteration: 46
# Loss: tensor(1402.4867, dtype=torch.float64)
# Epoch: 3 Iteration: 47
# Loss: tensor(1408.4026, dtype=torch.float64)
# Epoch: 3 Iteration: 48
# Loss: tensor(1407.5646, dtype=torch.float64)
# Epoch: 3 Iteration: 49
# Loss: tensor(1411.3359, dtype=torch.float64)
# Epoch: 4 Iteration: 0
# Loss: tensor(1403.6099, dtype=torch.float64)
# Epoch: 4 Iteration: 1
# Loss: tensor(1409.6596, dtype=torch.float64)
# Epoch: 4 Iteration: 2
# Loss: tensor(1408.4051, dtype=torch.float64)
# Epoch: 4 Iteration: 3
# Loss: tensor(1406.9375, dtype=torch.float64)
# Epoch: 4 Iteration: 4
# Loss: tensor(1408.4029, dtype=torch.float64)
# Epoch: 4 Iteration: 5
# Loss: tensor(1405.6612, dtype=torch.float64)
# Epoch: 4 Iteration: 6
# Loss: tensor(1408.8274, dtype=torch.float64)
# Epoch: 4 Iteration: 7
# Loss: tensor(1412.8754, dtype=torch.float64)
# Epoch: 4 Iteration: 8
# Loss: tensor(1408.1923, dtype=torch.float64)
# Epoch: 4 Iteration: 9
# Loss: tensor(1406.7051, dtype=torch.float64)
# Epoch: 4 Iteration: 10
# Loss: tensor(1411.8024, dtype=torch.float64)
# Epoch: 4 Iteration: 11
# Loss: tensor(1408.4028, dtype=torch.float64)
# Epoch: 4 Iteration: 12
# Loss: tensor(1409.0352, dtype=torch.float64)
# Epoch: 4 Iteration: 13
# Loss: tensor(1405.4609, dtype=torch.float64)
# Epoch: 4 Iteration: 14
# Loss: tensor(1406.7225, dtype=torch.float64)
# Epoch: 4 Iteration: 15
# Loss: tensor(1406.7196, dtype=torch.float64)
# Epoch: 4 Iteration: 16
# Loss: tensor(1406.2921, dtype=torch.float64)
# Epoch: 4 Iteration: 17
# Loss: tensor(1410.5234, dtype=torch.float64)
# Epoch: 4 Iteration: 18
# Loss: tensor(1407.9795, dtype=torch.float64)
# Epoch: 4 Iteration: 19
# Loss: tensor(1409.6817, dtype=torch.float64)
# Epoch: 4 Iteration: 20
# Loss: tensor(1406.2782, dtype=torch.float64)
# Epoch: 4 Iteration: 21
# Loss: tensor(1409.6833, dtype=torch.float64)
# Epoch: 4 Iteration: 22
# Loss: tensor(1403.9376, dtype=torch.float64)
# Epoch: 4 Iteration: 23
# Loss: tensor(1409.6871, dtype=torch.float64)
# Epoch: 4 Iteration: 24
# Loss: tensor(1405.6333, dtype=torch.float64)
# Epoch: 4 Iteration: 25
# Loss: tensor(1411.6176, dtype=torch.float64)
# Epoch: 4 Iteration: 26
# Loss: tensor(1408.1944, dtype=torch.float64)
# Epoch: 4 Iteration: 27
# Loss: tensor(1412.8784, dtype=torch.float64)
# Epoch: 4 Iteration: 28
# Loss: tensor(1403.1140, dtype=torch.float64)
# Epoch: 4 Iteration: 29
# Loss: tensor(1407.5576, dtype=torch.float64)
# Epoch: 4 Iteration: 30
# Loss: tensor(1407.3470, dtype=torch.float64)
# Epoch: 4 Iteration: 31
# Loss: tensor(1406.9245, dtype=torch.float64)
# Epoch: 4 Iteration: 32
# Loss: tensor(1407.9797, dtype=torch.float64)
# Epoch: 4 Iteration: 33
# Loss: tensor(1410.5209, dtype=torch.float64)
# Epoch: 4 Iteration: 34
# Loss: tensor(1406.4982, dtype=torch.float64)
# Epoch: 4 Iteration: 35
# Loss: tensor(1407.1323, dtype=torch.float64)
# Epoch: 4 Iteration: 36
# Loss: tensor(1407.3430, dtype=torch.float64)
# Epoch: 4 Iteration: 37
# Loss: tensor(1408.6172, dtype=torch.float64)
# Epoch: 4 Iteration: 38
# Loss: tensor(1405.0010, dtype=torch.float64)
# Epoch: 4 Iteration: 39
# Loss: tensor(1410.9698, dtype=torch.float64)
# Epoch: 4 Iteration: 40
# Loss: tensor(1404.7788, dtype=torch.float64)
# Epoch: 4 Iteration: 41
# Loss: tensor(1408.1963, dtype=torch.float64)
# Epoch: 4 Iteration: 42
# Loss: tensor(1405.8407, dtype=torch.float64)
# Epoch: 4 Iteration: 43
# Loss: tensor(1411.2069, dtype=torch.float64)
# Epoch: 4 Iteration: 44
# Loss: tensor(1410.5574, dtype=torch.float64)
# Epoch: 4 Iteration: 45
# Loss: tensor(1404.9918, dtype=torch.float64)
# Epoch: 4 Iteration: 46
# Loss: tensor(1410.3249, dtype=torch.float64)
# Epoch: 4 Iteration: 47
# Loss: tensor(1410.7394, dtype=torch.float64)
# Epoch: 4 Iteration: 48
# Loss: tensor(1407.9804, dtype=torch.float64)
# Epoch: 4 Iteration: 49
# Loss: tensor(1407.3538, dtype=torch.float64)
# Epoch: 5 Iteration: 0
# Loss: tensor(1406.5222, dtype=torch.float64)
# Epoch: 5 Iteration: 1
# Loss: tensor(1414.0501, dtype=torch.float64)
# Epoch: 5 Iteration: 2
# Loss: tensor(1413.4015, dtype=torch.float64)
# Epoch: 5 Iteration: 3
# Loss: tensor(1410.4845, dtype=torch.float64)
# Epoch: 5 Iteration: 4
# Loss: tensor(1408.4382, dtype=torch.float64)
# Epoch: 5 Iteration: 5
# Loss: tensor(1407.0251, dtype=torch.float64)
# Epoch: 5 Iteration: 6
# Loss: tensor(1400.7165, dtype=torch.float64)
# Epoch: 5 Iteration: 7
# Loss: tensor(1403.9064, dtype=torch.float64)
# Epoch: 5 Iteration: 8
# Loss: tensor(1407.7814, dtype=torch.float64)
# Epoch: 5 Iteration: 9
# Loss: tensor(1409.4611, dtype=torch.float64)
# Epoch: 5 Iteration: 10
# Loss: tensor(1409.9101, dtype=torch.float64)
# Epoch: 5 Iteration: 11
# Loss: tensor(1405.4008, dtype=torch.float64)
# Epoch: 5 Iteration: 12
# Loss: tensor(1400.3867, dtype=torch.float64)
# Epoch: 5 Iteration: 13
# Loss: tensor(1411.7807, dtype=torch.float64)
# Epoch: 5 Iteration: 14
# Loss: tensor(1407.8303, dtype=torch.float64)
# Epoch: 5 Iteration: 15
# Loss: tensor(1409.1693, dtype=torch.float64)
# Epoch: 5 Iteration: 16
# Loss: tensor(1411.1556, dtype=torch.float64)
# Epoch: 5 Iteration: 17
# Loss: tensor(1406.9315, dtype=torch.float64)
# Epoch: 5 Iteration: 18
# Loss: tensor(1406.9203, dtype=torch.float64)
# Epoch: 5 Iteration: 19
# Loss: tensor(1408.4301, dtype=torch.float64)
# Epoch: 5 Iteration: 20
# Loss: tensor(1408.4146, dtype=torch.float64)
# Epoch: 5 Iteration: 21
# Loss: tensor(1407.5543, dtype=torch.float64)
# Epoch: 5 Iteration: 22
# Loss: tensor(1407.9805, dtype=torch.float64)
# Epoch: 5 Iteration: 23
# Loss: tensor(1404.6345, dtype=torch.float64)
# Epoch: 5 Iteration: 24
# Loss: tensor(1415.3001, dtype=torch.float64)
# Epoch: 5 Iteration: 25
# Loss: tensor(1408.2072, dtype=torch.float64)
# Epoch: 5 Iteration: 26
# Loss: tensor(1410.6904, dtype=torch.float64)
# Epoch: 5 Iteration: 27
# Loss: tensor(1408.2301, dtype=torch.float64)
# Epoch: 5 Iteration: 28
# Loss: tensor(1403.9456, dtype=torch.float64)
# Epoch: 5 Iteration: 29
# Loss: tensor(1410.8944, dtype=torch.float64)
# Epoch: 5 Iteration: 30
# Loss: tensor(1407.1895, dtype=torch.float64)
# Epoch: 5 Iteration: 31
# Loss: tensor(1403.4435, dtype=torch.float64)
# Epoch: 5 Iteration: 32
# Loss: tensor(1403.1668, dtype=torch.float64)
# Epoch: 5 Iteration: 33
# Loss: tensor(1410.9576, dtype=torch.float64)
# Epoch: 5 Iteration: 34
# Loss: tensor(1407.3415, dtype=torch.float64)
# Epoch: 5 Iteration: 35
# Loss: tensor(1409.0843, dtype=torch.float64)
# Epoch: 5 Iteration: 36
# Loss: tensor(1404.7371, dtype=torch.float64)
# Epoch: 5 Iteration: 37
# Loss: tensor(1411.0999, dtype=torch.float64)
# Epoch: 5 Iteration: 38
# Loss: tensor(1411.1039, dtype=torch.float64)
# Epoch: 5 Iteration: 39
# Loss: tensor(1404.0781, dtype=torch.float64)
# Epoch: 5 Iteration: 40
# Loss: tensor(1410.4120, dtype=torch.float64)
# Epoch: 5 Iteration: 41
# Loss: tensor(1409.7344, dtype=torch.float64)
# Epoch: 5 Iteration: 42
# Loss: tensor(1406.6964, dtype=torch.float64)
# Epoch: 5 Iteration: 43
# Loss: tensor(1408.6214, dtype=torch.float64)
# Epoch: 5 Iteration: 44
# Loss: tensor(1407.5559, dtype=torch.float64)
# Epoch: 5 Iteration: 45
# Loss: tensor(1405.4571, dtype=torch.float64)
# Epoch: 5 Iteration: 46
# Loss: tensor(1403.1604, dtype=torch.float64)
# Epoch: 5 Iteration: 47
# Loss: tensor(1407.1416, dtype=torch.float64)
# Epoch: 5 Iteration: 48
# Loss: tensor(1410.9338, dtype=torch.float64)
# Epoch: 5 Iteration: 49
# Loss: tensor(1409.8803, dtype=torch.float64)
# Epoch: 6 Iteration: 0
# Loss: tensor(1410.7233, dtype=torch.float64)
# Epoch: 6 Iteration: 1
# Loss: tensor(1406.9297, dtype=torch.float64)
# Epoch: 6 Iteration: 2
# Loss: tensor(1408.8233, dtype=torch.float64)
# Epoch: 6 Iteration: 3
# Loss: tensor(1410.5035, dtype=torch.float64)
# Epoch: 6 Iteration: 4
# Loss: tensor(1408.4042, dtype=torch.float64)
# Epoch: 6 Iteration: 5
# Loss: tensor(1408.8236, dtype=torch.float64)
# Epoch: 6 Iteration: 6
# Loss: tensor(1410.4949, dtype=torch.float64)
# Epoch: 6 Iteration: 7
# Loss: tensor(1407.1582, dtype=torch.float64)
# Epoch: 6 Iteration: 8
# Loss: tensor(1407.5752, dtype=torch.float64)
# Epoch: 6 Iteration: 9
# Loss: tensor(1408.4071, dtype=torch.float64)
# Epoch: 6 Iteration: 10
# Loss: tensor(1409.2418, dtype=torch.float64)
# Epoch: 6 Iteration: 11
# Loss: tensor(1404.0056, dtype=torch.float64)
# Epoch: 6 Iteration: 12
# Loss: tensor(1407.7702, dtype=torch.float64)
# Epoch: 6 Iteration: 13
# Loss: tensor(1407.1313, dtype=torch.float64)
# Epoch: 6 Iteration: 14
# Loss: tensor(1408.6208, dtype=torch.float64)
# Epoch: 6 Iteration: 15
# Loss: tensor(1405.1972, dtype=torch.float64)
# Epoch: 6 Iteration: 16
# Loss: tensor(1405.1869, dtype=torch.float64)
# Epoch: 6 Iteration: 17
# Loss: tensor(1406.9145, dtype=torch.float64)
# Epoch: 6 Iteration: 18
# Loss: tensor(1406.0465, dtype=torch.float64)
# Epoch: 6 Iteration: 19
# Loss: tensor(1405.1716, dtype=torch.float64)
# Epoch: 6 Iteration: 20
# Loss: tensor(1407.1519, dtype=torch.float64)
# Epoch: 6 Iteration: 21
# Loss: tensor(1405.6123, dtype=torch.float64)
# Epoch: 6 Iteration: 22
# Loss: tensor(1404.7295, dtype=torch.float64)
# Epoch: 6 Iteration: 23
# Loss: tensor(1406.9423, dtype=torch.float64)
# Epoch: 6 Iteration: 24
# Loss: tensor(1412.2502, dtype=torch.float64)
# Epoch: 6 Iteration: 25
# Loss: tensor(1408.6874, dtype=torch.float64)
# Epoch: 6 Iteration: 26
# Loss: tensor(1404.7391, dtype=torch.float64)
# Epoch: 6 Iteration: 27
# Loss: tensor(1414.4861, dtype=torch.float64)
# Epoch: 6 Iteration: 28
# Loss: tensor(1406.9134, dtype=torch.float64)
# Epoch: 6 Iteration: 29
# Loss: tensor(1405.0247, dtype=torch.float64)
# Epoch: 6 Iteration: 30
# Loss: tensor(1405.8897, dtype=torch.float64)
# Epoch: 6 Iteration: 31
# Loss: tensor(1412.3722, dtype=torch.float64)
# Epoch: 6 Iteration: 32
# Loss: tensor(1410.2800, dtype=torch.float64)
# Epoch: 6 Iteration: 33

# %%
torch.save(model.state_dict(), 'trained_mdn')

# %% [markdown]
# The following was an attempt at generating handwriting without MDN (non-probabilistic). Didn't work lolz

# %%
class GeneratorCellDeterministic(torch.nn.Module):
    def __init__(self, hidden_size):
        super(GeneratorCellDeterministic, self).__init__()

        self.gru = torch.nn.GRU(input_size=3, hidden_size=hidden_size, batch_first=True)
        self.hidden_size= hidden_size
        self.mixture_size = mixture_size

        # for generating x-y-EOS from gru output
        self.linear = torch.nn.Linear(hidden_size, 3)

    def forward(self, input_batch, seq_length):
        batch_size = input_batch.size()[0]
        output_batch = torch.zeros(batch_size, seq_length, 3)
        hidden = torch.zeros(1, batch_size, self.hidden_size, dtype=torch.double)
        for i in range(seq_length):
            output, hidden = self.gru(input_batch[:, i, :].unsqueeze(1), hidden)
            output = torch.nn.functional.relu(self.linear(output))
            output_batch[:, i, :] = output.squeeze(1)
            
        return output_batch
    
    # Given some (x, y, EOS), return the next (x, y, EOS) and the next hidden state
    def get_next(self, input, hidden):
        output, hidden = self.gru(input.view(1, 1, 3), hidden)
        
        # get rid of sequence index in output
        output = output.squeeze(1)
        
        output = torch.nn.functional.relu(self.linear(output))
            
        return output, hidden

# %%
def sequence_loss(input_batch, output_batch, min_length, batch_size):
    #mean-squared error
    ret = 0
    
    # iterate through batch
    for batch_index, sequence in enumerate(input_batch):
        # iterate through data points in sequence
        for seq_index in range(min_length - 1):
            data_point = sequence[seq_index + 1]
            
            err = output_batch[batch_index, seq_index, :] - data_point
            ret += torch.dot(err, err)
            
            
    return ret/(batch_size*min_length) # we have sum over batch, now return mean

# %%
# Training loop
n_epochs = 100
n_iters = 50
hidden_size = 16
batch_size = 15

model = GeneratorCellDeterministic(hidden_size).double()
optimizer = torch.optim.SGD(model.parameters(), lr=0.0001, momentum=0.9)

losses = np.zeros(n_epochs) # For plotting

indices = list(range(len(points_list))) # Indices for random sampling (for batches)

# %%
for epoch in range(n_epochs):
    for iter in range(n_iters):
        print('Epoch: ' + str(epoch) + ' Iteration: ' + str(iter))
        index_list = random.sample(indices, batch_size) # random sampling of indices
        min_length = min([points_lengths[i] for i in index_list]) # list of sequence lengths
        input_batch = torch.autograd.Variable(torch.tensor([points_list[i][0:min_length] for i in index_list], dtype=torch.double))
        
        output_batch = model.forward(input_batch, min_length)

        optimizer.zero_grad()
        loss = sequence_loss(input_batch, output_batch, min_length, batch_size)
        loss.backward()
        optimizer.step()
        
        print('Loss: ' + str(loss.data))
    losses[epoch] = loss.data

# %% [markdown]
# Next we have a plotter script to see what our model generates

# %%
import matplotib.pyplot as plt

# %%
output_x = [895] # list of x outputs. this is the initial x
output_y = [992] # list of y outputs. this is the initial y
eos = 0 # does the previous output correspond to an eos
for i in range(1):
    input = torch.tensor([output_x[-1], output_y[-1], eos])
    gmm = model.get_next(input)
    print(gmm)
    #not done
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-b1d86ea71846> in <module>
#       4 for i in range(1):
#       5     input = torch.tensor([output_x[-1], output_y[-1], eos])
# ----> 6     gmm = model.get_next(input)
#       7     print(gmm)
#       8     #not done
#
# TypeError: get_next() missing 1 required positional argument: 'hidden'

# %%
output.show()
# Out:
# Epoch: 0 Iteration: 0
# Loss: tensor(1527.4976, dtype=torch.float64)
# Epoch: 0 Iteration: 1
# Loss: tensor(1510.0288, dtype=torch.float64)
# Epoch: 0 Iteration: 2
# Loss: tensor(1480.9610, dtype=torch.float64)
# Epoch: 0 Iteration: 3
# Loss: tensor(1460.9214, dtype=torch.float64)
# Epoch: 0 Iteration: 4
# Loss: tensor(1447.1385, dtype=torch.float64)
# Epoch: 0 Iteration: 5
# Loss: tensor(1430.4561, dtype=torch.float64)
# Epoch: 0 Iteration: 6
# Loss: tensor(1420.9412, dtype=torch.float64)
# Epoch: 0 Iteration: 7
# Loss: tensor(1415.7738, dtype=torch.float64)
# Epoch: 0 Iteration: 8
# Loss: tensor(1412.8102, dtype=torch.float64)
# Epoch: 0 Iteration: 9
# Loss: tensor(1411.8943, dtype=torch.float64)
# Epoch: 0 Iteration: 10
# Loss: tensor(1407.1174, dtype=torch.float64)
# Epoch: 0 Iteration: 11
# Loss: tensor(1412.8093, dtype=torch.float64)
# Epoch: 0 Iteration: 12
# Loss: tensor(1409.8718, dtype=torch.float64)
# Epoch: 0 Iteration: 13
# Loss: tensor(1404.9797, dtype=torch.float64)
# Epoch: 0 Iteration: 14
# Loss: tensor(1408.1084, dtype=torch.float64)
# Epoch: 0 Iteration: 15
# Loss: tensor(1408.9306, dtype=torch.float64)
# Epoch: 0 Iteration: 16
# Loss: tensor(1403.8080, dtype=torch.float64)
# Epoch: 0 Iteration: 17
# Loss: tensor(1412.7560, dtype=torch.float64)
# Epoch: 0 Iteration: 18
# Loss: tensor(1407.5541, dtype=torch.float64)
# Epoch: 0 Iteration: 19
# Loss: tensor(1412.8116, dtype=torch.float64)
# Epoch: 0 Iteration: 20
# Loss: tensor(1414.2058, dtype=torch.float64)
# Epoch: 0 Iteration: 21
# Loss: tensor(1410.1237, dtype=torch.float64)
# Epoch: 0 Iteration: 22
# Loss: tensor(1416.0610, dtype=torch.float64)
# Epoch: 0 Iteration: 23
# Loss: tensor(1412.6573, dtype=torch.float64)
# Epoch: 0 Iteration: 24
